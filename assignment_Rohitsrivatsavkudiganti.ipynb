# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
l = 1.0 # total length 

nx = 11 # total no of grid points 

dx = l/(nx -1.0)  # given in queation as 0.1 

x = np.linspace(0,1,nx)

sr = 1 # source term 

alpha = 0.001 # thermal difffusivity 

dt = 0.1  # time spacing 


r = (dt * alpha) / (dx*dx)

print(r) # stable r value
# Out:
# 0.009999999999999998

# %%
def dis(i, sr, alpha):
    r = (dt * alpha) / (dx*dx)
    return r * tn[i+1] + (1-2.0 *r) * tn[i] + r* tn[i-1] + sr *dt

# %%
def calcu(alpha, sr):
    time = dt
    tn = np.zeros(nx)
 
    r = (dt * alpha) / (dx*dx)
    while time<maxtime :
        for i in range (1,nx-1): 
            tn1[i] = r * tn[i+1] + (1-2.0 *r) * tn[i] + r* tn[i-1] + sr *dt
        
        tn1[0] = 1.0
        tn1[nx-1] = 2.0

        tn = tn1.copy()
        
    

#         print(f'time: {time}')
        time = time + dt

# %%
maxtime = 5.0

time = 0.1

calcu(alpha=0.01, sr=1.0)



print(' for case source is 1.0 with varying values of alpha ')
    
print('case 1 alpha 0.01')

print('the finial solution after time 5 seconds is for alpha 0.01 ')

print(tn1)

plt.plot(x,tn1, label = 'alpha is 0.01')
plt.ylim(0,6)



calcu(alpha=0.025, sr=1.0)
    

print('the finial solution after time 5 seconds is for alpha 0.025  ')

print(tn1)

plt.plot(x,tn1, label = 'alpha 0.025')
plt.ylim(0,6)



calcu(alpha=0.005, sr=1.0)
    

print('the finial solution after time 5 seconds is for alpha 0.005 ')

print(tn1)

plt.plot(x,tn1, label = 'alpha 0.005')
plt.ylim(0,10)

plt.legend()
# Out:
#  for case source is 1.0 with varying values of alpha
# case 1 alpha 0.01
# the finial solution after time 5 seconds is for alpha 0.01
# [1.         2.81557648 3.90488373 4.51056787 4.82091505 4.95707106
#  4.96742775 4.82384465 4.41793919 3.56173107 2.        ]
# the finial solution after time 5 seconds is for alpha 0.025
# [1.         2.2654935  3.19272632 3.83753351 4.24446827 4.44244431
#  4.44182165 4.23325118 3.78844399 3.06284687 2.        ]
# the finial solution after time 5 seconds is for alpha 0.005
# [1.         3.31857857 4.39331969 4.81812716 4.96275042 5.01134457
#  5.02980468 4.99548981 4.76099976 3.96995043 2.        ]

# %%
maxtime = 5.0

time = 0.1

calcu(alpha=0.01, sr=2.0)



print(' for case source is 2.0 with varying values of alpha ')
    
print('case 1 alpha 0.01')

print('the finial solution after time 5 seconds is for alpha 0.01 ')

print(tn1)

plt.plot(x,tn1 , label = ' alpha 0.01')




calcu(alpha=0.025, sr=2.0)
    

print('the finial solution after time 5 seconds is for alpha 0.025  ')

print(tn1)

plt.plot(x,tn1, label = ' alpha 0.025')




calcu(alpha=0.005, sr=2.0)
    

print('the finial solution after time 5 seconds is for alpha 0.005 ')

print(tn1)

plt.plot(x,tn1, label = ' alpha 0.005')

plt.legend()
# Out:
#  for case source is 2.0 with varying values of alpha
# case 1 alpha 0.01
# the finial solution after time 5 seconds is for alpha 0.01
# [1.         4.87272273 7.262092   8.62676179 9.3224308  9.57515928
#  9.4689435  8.94003857 7.77514746 5.61887732 2.        ]
# the finial solution after time 5 seconds is for alpha 0.025
# [1.         3.60350722 5.51397728 6.82804107 7.62262641 7.94743201
#  7.81997978 7.22375874 6.10969495 4.40086059 2.        ]
# the finial solution after time 5 seconds is for alpha 0.005
# [1.         5.98537362 8.41705122 9.4512725  9.8315179  9.93889137
#  9.89857216 9.62863514 8.78473129 6.63674547 2.        ]

# %%
maxtime = 5.0

time = 0.1

calcu(alpha=0.01, sr=3.0)



print(' for case source is 3.0 with varying values of alpha ')
    
print('case 1 alpha 0.01')

print('the finial solution after time 5 seconds is for alpha 0.01 ')

print(tn1)

plt.plot(x,tn1 , label = 'alpha 0.01')




calcu(alpha=0.025, sr=3.0)
    

print('the finial solution after time 5 seconds is for alpha 0.025  ')

print(tn1)

plt.plot(x,tn1 , label = 'alpha 0.025')




calcu(alpha=0.005, sr=3.0)
    

print('the finial solution after time 5 seconds is for alpha 0.005 ')

print(tn1)

plt.plot(x,tn1, label = 'alpha 0.005')

plt.legend()
# Out:
#  for case source is 3.0 with varying values of alpha
# case 1 alpha 0.01
# the finial solution after time 5 seconds is for alpha 0.01
# [ 1.          6.92986898 10.61930026 12.74295572 13.82394655 14.1932475
#  13.97045925 13.0562325  11.13235573  7.67602357  2.        ]
# the finial solution after time 5 seconds is for alpha 0.025
# [ 1.          4.94152094  7.83522825  9.81854864 11.00078454 11.4524197
#  11.19813791 10.21426631  8.43094592  5.73887431  2.        ]
# the finial solution after time 5 seconds is for alpha 0.005
# [ 1.          8.65216866 12.44078274 14.08441783 14.70028538 14.86643818
#  14.76733964 14.26178048 12.80846282  9.30354052  2.        ]

# %% [markdown]
#  # answer for question b
#
#
#     for increase in value of source term the gradient of  teamperature over the length is increasing  as we can see from the above plot
#
#
#     and for the value of increasing alpha as the value of alpha increasing the peak the cureve decreasing resulting in more diffusion of temperature
